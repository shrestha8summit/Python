# %%
file =  open("hello.txt",'w')

file.write("Hi!")

file.close()

# %%
file = open("hello.txt","a")
file.write("I am Summit")
file.close()

# %%
file = open("hello.txt","r")
print(file.readlines(1))
file.close()
# Out:
# ['Hi!I am Summit']

# %%
# basic operation in text file, check the file id null or not if yes the print the data otherwise input data and read it 
#and then finally copy in other file

file = open("assignment.txt","w+")
file.write("Hello world! I am Summit Shrestha")
data=print(file.readlines(1))
print(data)
file2=open("copied.txt","w+")
data = repr(print(file.readline(1)))
print(file2.readlines(1))
file2.write(data)
file2.close()
file.close()
# Out:
# []
# None
#
# []

# %%
# check !null, write, read ,append, create 2 file, copy data from one file and paste to another
import shutil

def is_file_empty_3(file_name):
    """ Check if file is empty by reading first character in it"""
    # open ile in read mode
    with open(file_name, 'r') as read_obj:
        # read first character
        one_char = read_obj.read(1)
        # if not fetched then file is empty
        if not one_char:
           return True
    return False

file_path = 'Text doc.txt'
 
# check if file is empty
is_empty = is_file_empty_3(file_path)

if (is_empty):

    #write file
    file = open('Text doc.txt', 'w+')
    file.write("hello world")
    file.close()

   
else:
     #read file
    file = open('Text doc.txt', 'r')
    print(file.readlines(1))
    file.close()
    
#append file
file = open('Text doc.txt', 'a')
file.write(" ! I am good. ")
file.close()



#copy file
original = r'C:\Users\This pc\python\Text doc.txt'
target = r'C:\Users\This pc\python\hello.txt'
shutil.copyfile(original, target)
file = open('hello.txt', 'r')
print(file.readlines(1))
file.close()
# Out:
# ['hello world ! I am good. ']

# %%
import os                                 #helps to perform operration in our OS
import shutil                             #helps to copy an dpaste file 
if os.path.exists(r"record.txt") == 1:   #checking there is record.txt or not
    if os.stat("record.txt").st_size == 0:
        f=open("record.txt","w+")
        name = input("Enter your name ")
        f.write(name)
        print(f.read(1))
        f.close()
    else:
        f=open("record.txt","a+")
        name = input("Enter your name ")
        f.write(name)
        print(f.read(1))
        f.close()
        
else:
    f=open("record.txt","w+")
    name = input("Enter your name ")
    f.write(name)
    print(f.read(1))
    f.close()

    
odir=r"record.txt"
filec=open("copy.txt","w")
filec.close()
cdir=r"copy.txt"
shutil.copyfile(odir,cdir)
filec =open("copy.txt","r")
print(filec.read())
filec.close()
# Out:
# 		 Entery fro new records of latest academic year
# Enter your name:	abbde
# Enter your roll number:	45
# Enter your age :	19
# Enter your home addressasdw
# Enter your phone number:	6548362468
# Enter the marks obtained in physics	65
# Enter the marks obtained in maths	59
# Enter the marks obtained in N.C		98
# Enter the marks obtained in PTTL	68
# Enter the marks obtained in c prog.	48
#
#  Is there any data remaining for entry 1 or 0: 	 0
#
#
#
# abbde	asdw

# %%
import os                                 #helps to perform operration in our OS
import shutil 

def write():
    file= open("record.txt","a")
    name= input("Enter name of student:\t")
    age = int(input("Enter age of the student:\t"))
    roll= int(input("Enter roll no. of the student:\t"))
    gpa = int(input("Enter your gpa"))
    file.write(f"{name},{age},{roll},{gpa}\n")
    print(f"Record for  added successfully!")
    file.close()
    file.close()

def append():
    file= open("record.txt","a")
    name= input("Enter name of student:\t")
    age = int(input("Enter age of the student:\t"))
    roll= int(input("Enter roll no. of the student:\t"))
    gpa = float(input("Enter your gpa"))
    file.write(f"{name},{age},{roll},{gpa}\n")
    print(f"Record for  added successfully!")
    file.close()
    

def display():
    filec =open("record.txt","r")
    print(filec.read())
    filec.close() 

while True:
    if os.path.exists(r"record.txt") == 1:
        while os.stat("record.txt").st_size == 0:
            print("\nStudent Record Management System\n")
            write()
        else:
            print("\nStudent Record Management System")
            print("1. Add Student Record")
            print("2. Display Student Records")
            print("3. Quit")
            choice = input("Enter your choice (1/2): ")

            if choice == '1':
                append()
            elif choice == '2':
                display()            
    else:
        print("\nStudent Record Management System")
        write()
    
    yn=int(input("DO you want to perform other operrations too ? 1 or 0: \t"))
    if yn == 0:
        break
 
    
odir=r"record.txt"
filec=open("copy.txt","w")
filec.close()
cdir=r"copy.txt"
shutil.copyfile(odir,cdir)
print("Your sata have been copied to anotehr location also.")
# Out:
# Enter name of student:	abcd
# Enter age of the student:	15
# Enter roll no. of the student:	16
# Enter your gpa9

# %%
import os                                 #helps to perform operration in our OS
import shutil 

def write():
    file= open("record.txt","a")
    name= input("Enter name of student:\t")
    age = int(input("Enter age of the student:\t"))
    roll= int(input("Enter roll no. of the student:\t"))
    gpa = int(input("Enter your gpa"))
    file.write(f"{name},{age},{roll},{gpa}\n")
    print(f"Record for  added successfully!")
    file.close()

def append():
    file= open("record.txt","a")
    name= input("Enter name of student:\t")
    age = int(input("Enter age of the student:\t"))
    roll= int(input("Enter roll no. of the student:\t"))
    gpa = float(input("Enter your gpa"))
    file.write(f"{name},{age},{roll},{gpa}\n")
    print(f"Record for  added successfully!")
    file.close()
    

def display():
    filec =open("record.txt","r")
    print(filec.read())
    filec.close() 

while True:
    if os.path.exists(r"record.txt") == 1:
        while os.stat("record.txt").st_size == 0:
            print("\nStudent Record Management System\n")
            write()
        else:
            print("\nStudent Record Management System")
            print("1. Add Student Record")
            print("2. Display Student Records")
            choice = input("Enter your choice (1/2): ")

            if choice == '1':
                append()
            elif choice == '2':
                display()            
    else:
        print("\nStudent Record Management System")
        write()
    
    yn=int(input("DO you want to perform other operrations too ? 1 or 0: \t"))
    if yn == 0:
        break
 
    
odir=r"record.txt"
filec=open("copy.txt","w")
filec.close()
cdir=r"copy.txt"
shutil.copyfile(odir,cdir)
print("Your data have been copied to anotehr location also.")
# Out:
# Student Record Management System
# Enter name of student:	abcd
# Enter age of the student:	15
# Enter roll no. of the student:	19
# Enter your gpa6
# Record for  added successfully!
# DO you want to perform other operrations too ? 1 or 0: 	1
#
# Student Record Management System
# 1. Add Student Record
# 2. Display Student Records
# Enter your choice (1/2): 1
# Enter name of student:	Raj
# Enter age of the student:	15
# Enter roll no. of the student:	6
# Enter your gpa7
# Record for  added successfully!
# DO you want to perform other operrations too ? 1 or 0: 	1
#
# Student Record Management System
# 1. Add Student Record
# 2. Display Student Records
# Enter your choice (1/2): 2
# abcd,15,19,6
# Raj,15,6,7.0
#
# DO you want to perform other operrations too ? 1 or 0: 	0
# Your sata have been copied to anotehr location also.
